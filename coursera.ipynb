# %%
import pandas as pd

# %%
df = pd.read_csv(D:/COURSERA/PYTHON/kc_house_data_NaN.csv)
# Out:
#   Cell In[2], line 1
#     df = pd.read_csv(D:/COURSERA/PYTHON/kc_house_data_NaN.csv)
#                       ^
# SyntaxError: invalid syntax

# %%
df = pd.read_csv('D:/COURSERA/PYTHON/kc_house_data_NaN.csv')

# %%
print(df.dtypes)
# Out:
# Unnamed: 0         int64
# id                 int64
# date              object
# price            float64
# bedrooms         float64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
import pandas as pd

# %%
df=pd.read_csv('kc_house_data_NaN.csv')

# %% [markdown]
# df.drop(['id','Unnamed: 0'], axis=1, inplace=True)
# df.describe()

# %%
import pandas as pd

# %%
df = pd.read_csv('kc_house_data_NaN.csv')
un_fl_count = df['floors'].value_counts().to_frame()
un_fl_count
# Out:
#      floors
# 1.0   10680
# 2.0    8241
# 1.5    1910
# 3.0     613
# 2.5     161
# 3.5       8

# %%
import seaborn as sns

# %%
sns.boxplot(x='waterfront', y='price', data=df)
# Out:
# <Axes: xlabel='waterfront', ylabel='price'>

# %%
import matplotlib.pyplot as pyplot

# %%
df = pd.read_csv('kc_house_data_NaN.csv')
sns.regplot(x='sqft_above', y='price', data=df)
# Out:
# <Axes: xlabel='sqft_above', ylabel='price'>

# %%
from sklearn.linear_model import LinearRegression
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from sklearn.linear_model import LinearRegression
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
pip install sklearn

# %%
import pandas as pd

# %%
from sklearn.linear_model import LinearRegression
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 from sklearn.linear_model import LinearRegression
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
df=pd.read_csv('kc_house_data_NaN.csv')
x = df[('sqft_living')]
y = df['price']

lm = LinearRegression()
lm.fit(x, y)

r_2 = lm.score(x, y)
print('r^2:', r_2)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 2
#       1 import pandas as pd
# ----> 2 from sklearn.linear_model import LinearRegression
#       3 df=pd.read_csv('kc_house_data_NaN.csv')
#       4 x = df[('sqft_living')]
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
pip install -U scikit-learn
# Out:
# ...
#
# ...
#      ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#      ---------------------------------------- 0.1/8.3 MB ? eta -:--:--
#      - -------------------------------------- 0.2/8.3 MB 1.7 MB/s eta 0:00:05
#      - -------------------------------------- 0.3/8.3 MB 1.5 MB/s eta 0:00:06
#      - -------------------------------------- 0.3/8.3 MB 1.5 MB/s eta 0:00:06
#      - -------------------------------------- 0.4/8.3 MB 1.5 MB/s eta 0:00:06
#      -- ------------------------------------- 0.5/8.3 MB 1.4 MB/s eta 0:00:06
#      --- ------------------------------------ 0.6/8.3 MB 1.8 MB/s eta 0:00:05
#      --- ------------------------------------ 0.7/8.3 MB 1.7 MB/s eta 0:00:05
#      --- ------------------------------------ 0.7/8.3 MB 1.7 MB/s eta 0:00:05
#      --- ------------------------------------ 0.7/8.3 MB 1.7 MB/s eta 0:00:05
#      ---- ----------------------------------- 0.9/8.3 MB 1.6 MB/s eta 0:00:05
# ...

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
df=pd.read_csv('kc_house_data_NaN.csv')
x = df[('sqft_living')]

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
df=pd.read_csv('kc_house_data_NaN.csv')
x = df[('sqft_living')]
y = df['price']

reg = LinearRegression()
reg.fit(x, y)

r_2 = reg.score(x, y)
print('r^2:', r_2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 8
#       5 y = df['price']
#       7 reg = LinearRegression()
# ----> 8 reg.fit(x, y)
#      10 r_2 = reg.score(x, y)
#      11 print('r^2:', r_2)
#
# File c:\Users\Kamel\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:648, in LinearRegression.fit(self, X, y, sample_weight)
#     644 n_jobs_ = self.n_jobs
#     646 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 648 X, y = self._validate_data(
#     649     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650 )
#     652 sample_weight = _check_sample_weight(
#     653     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     654 )
#     656 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     657     X,
#     658     y,
#    (...)
# ...

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
df=pd.read_csv('kc_house_data_NaN.csv')
x = df[('sqft_living')]
y = df['price']

reg = LinearRegression()
reg.fit(x, y)

r_2 = reg.score(x, y)
print("r^2: {:.4f}".format(r_2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 8
#       5 y = df['price']
#       7 reg = LinearRegression()
# ----> 8 reg.fit(x, y)
#      10 r_2 = reg.score(x, y)
#      11 print("r^2: {:.4f}".format(r_2))
#
# File c:\Users\Kamel\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:648, in LinearRegression.fit(self, X, y, sample_weight)
#     644 n_jobs_ = self.n_jobs
#     646 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 648 X, y = self._validate_data(
#     649     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650 )
#     652 sample_weight = _check_sample_weight(
#     653     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     654 )
#     656 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     657     X,
#     658     y,
#    (...)
# ...

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
df=pd.read_csv('kc_house_data_NaN.csv')
x = df[('sqft_living')]
y = df['price']

reg = LinearRegression()
reg.fit(x,y)

r_2 = reg.score(x,y)
print("r^2: {:.4f}".format(r_2))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 8
#       5 y = df['price']
#       7 reg = LinearRegression()
# ----> 8 reg.fit(x,y)
#      10 r_2 = reg.score(x,y)
#      11 print("r^2: {:.4f}".format(r_2))
#
# File c:\Users\Kamel\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:648, in LinearRegression.fit(self, X, y, sample_weight)
#     644 n_jobs_ = self.n_jobs
#     646 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 648 X, y = self._validate_data(
#     649     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650 )
#     652 sample_weight = _check_sample_weight(
#     653     sample_weight, X, dtype=X.dtype, only_non_negative=True
#     654 )
#     656 X, y, X_offset, y_offset, X_scale = _preprocess_data(
#     657     X,
#     658     y,
#    (...)
# ...

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv('kc_house_data_NaN.csv')

# %%
X = df[['sqft_living']]

Y = df['price']

reg = LinearRegression()

reg.fit(X,Y)

R2 = reg.score(X,Y)

print("R2:",R2)
# Out:
# R2: 0.4928532179037931

# %%
elementos = ["floors", "waterfront", "lat", "bedrooms", "sqft_basement", "view", "bathrooms", "sqft_living15", "sqft_above", "grade", "sqft_living"]

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
df = pd.read_csv('kc_house_data_NaN.csv')
df.dropna(inplace=True)
elementos = ["floors", "waterfront", "lat", "bedrooms", "sqft_basement", "view", "bathrooms", "sqft_living15", "sqft_above", "grade", "sqft_living"]
X = df['elementos']
Y = df['price']
reg = LinearRegression().fit(X,Y)
R2 = reg.score(X,Y)
print("R2:", R2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Kamel\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\Users\Kamel\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\Kamel\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'elementos'
#
# ...

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import reg_score
df = pd.read_csv('kc_house_data_NaN.csv')
df.dropna(inplace=True)
X= df[['floors','waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms', 'sqft_living15', 'sqft_above', 'grade', 'sqft_living']]
Y= df['price']

reg = LinearRegression().fit(X,Y)

Y_predict = reg_predict(X)

R2 = reg.score(Y, Y_predict)

print("R2", R2)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[34], line 3
#       1 import pandas as pd
#       2 from sklearn.linear_model import LinearRegression
# ----> 3 from sklearn.metrics import reg_score
#       4 df = pd.read_csv('kc_house_data_NaN.csv')
#       5 df.dropna(inplace=True)
#
# ImportError: cannot import name 'reg_score' from 'sklearn.metrics' (c:\Users\Kamel\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\__init__.py)

# %%
import reg_score
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 import reg_score
#
# ModuleNotFoundError: No module named 'reg_score'

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import reg.score
df = pd.read_csv('kc_house_data_NaN.csv')
df.dropna(inplace=True)
X= df[['floors','waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms', 'sqft_living15', 'sqft_above', 'grade', 'sqft_living']]
Y= df['price']

reg = LinearRegression().fit(X,Y)

Y_predict = reg_predict(X)

R2 = reg.score(Y, Y_predict)

print("R2", R2)
# Out:
#   Cell In[36], line 3
#     from sklearn.metrics import reg.score
#                                    ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
df = pd.read_csv('kc_house_data_NaN.csv')
df.dropna(inplace=True)
X= df[['floors','waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms', 'sqft_living15', 'sqft_above', 'grade', 'sqft_living']]
Y= df['price']

reg = LinearRegression().fit(X,Y)

Y_predict = reg_predict(X)

R2 = r2_score(Y, Y_predict)

print("R2", R2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 11
#       7 Y= df['price']
#       9 reg = LinearRegression().fit(X,Y)
# ---> 11 Y_predict = reg_predict(X)
#      13 R2 = r2_score(Y, Y_predict)
#      15 print("R2", R2)
#
# NameError: name 'reg_predict' is not defined

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
df = pd.read_csv('kc_house_data_NaN.csv')
df.dropna(inplace=True)
X= df[['floors','waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms', 'sqft_living15', 'sqft_above', 'grade', 'sqft_living']]
Y= df['price']

reg = LinearRegression().fit(X,Y)

Y_predict = reg.predict(X)

R2 = r2_score(Y, Y_predict)

print("R2", R2)
# Out:
# R2 0.6578397722224434

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
df = pd.read_csv('kc_house_data_NaN.csv')
X= df[['floors','waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms', 'sqft_living15', 'sqft_above', 'grade', 'sqft_living']]
Y= df['price']

reg = LinearRegression().fit(X,Y)

Y_predict = reg.predict(X)

R2 = r2_score(Y, Y_predict)

print("R2", R2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 8
#       5 X= df[['floors','waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms', 'sqft_living15', 'sqft_above', 'grade', 'sqft_living']]
#       6 Y= df['price']
# ----> 8 reg = LinearRegression().fit(X,Y)
#      10 Y_predict = reg.predict(X)
#      12 R2 = r2_score(Y, Y_predict)
#
# File c:\Users\Kamel\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_base.py:648, in LinearRegression.fit(self, X, y, sample_weight)
#     644 n_jobs_ = self.n_jobs
#     646 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 648 X, y = self._validate_data(
#     649     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     650 )
#     652 sample_weight = _check_sample_weight(
# ...

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
df = pd.read_csv('kc_house_data_NaN.csv')
df.dropna(inplace=True)
X= df[['floors','waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms', 'sqft_living15', 'sqft_above', 'grade', 'sqft_living']]
Y= df['price']
reg = LinearRegression().fit(X,Y)
predict_Y = reg.predict(X)
R2 = r2_score(Y, predict_Y)
print("R2", R2)
# Out:
# R2 0.6578397722224434

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
df = pd.read_csv('kc_house_data_NaN.csv')
df.dropna(inplace=True)
X= df[['floors','waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms', 'sqft_living15', 'sqft_above', 'grade', 'sqft_living']]
Y= df['price']
estimate = [('Scale', StandardScaler()), ('Polynomial', PolynomialFeatures(include_bias=True)), ('model', LinearRegression())]
pipeline = pipeline(estimate)
pipeline.fit(X,Y)
R2 = pipeline.score(X,Y)
print("R2:", R2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 10
#       8 Y= df['price']
#       9 estimate = [('Scale', StandardScaler()), ('Polynomial', PolynomialFeatures(include_bias=True)), ('model', LinearRegression())]
# ---> 10 pipeline = pipeline(estimate)
#      11 pipeline.fit(X,Y)
#      12 R2 = pipeline.score(X,Y)
#
# NameError: name 'pipeline' is not defined

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
df = pd.read_csv('kc_house_data_NaN.csv')
df.dropna(inplace=True)
X= df[['floors','waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms', 'sqft_living15', 'sqft_above', 'grade', 'sqft_living']]
Y= df['price']
estimate = [('Scale', StandardScaler()), ('Polynomial', PolynomialFeatures(include_bias=True)), ('model', LinearRegression())]
pipe = pipeline(estimate)
pipeline.fit(X,Y)
R2 = pipe.score(X,Y)
print("R2:", R2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 10
#       8 Y= df['price']
#       9 estimate = [('Scale', StandardScaler()), ('Polynomial', PolynomialFeatures(include_bias=True)), ('model', LinearRegression())]
# ---> 10 pipe = pipeline(estimate)
#      11 pipeline.fit(X,Y)
#      12 R2 = pipe.score(X,Y)
#
# NameError: name 'pipeline' is not defined

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
df = pd.read_csv('kc_house_data_NaN.csv')
df.dropna(inplace=True)
X= df[['floors','waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms', 'sqft_living15', 'sqft_above', 'grade', 'sqft_living']]
Y= df['price']
estimate = [('Scale', StandardScaler()), ('Polynomial', PolynomialFeatures(include_bias=False)), ('model', LinearRegression())]
pipe = pipeline(estimate)
pipe.fit(X,Y)
R2 = pipe.score(X,Y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 10
#       8 Y= df['price']
#       9 estimate = [('Scale', StandardScaler()), ('Polynomial', PolynomialFeatures(include_bias=False)), ('model', LinearRegression())]
# ---> 10 pipe = pipeline(estimate)
#      11 pipe.fit(X,Y)
#      12 R2 = pipe.score(X,Y)
#
# NameError: name 'pipeline' is not defined

# %%
import pipeline as pipeline

# %%
import pandas as pd
import pipeline as pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
df = pd.read_csv('kc_house_data_NaN.csv')
df.dropna(inplace=True)
X= df[['floors','waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms', 'sqft_living15', 'sqft_above', 'grade', 'sqft_living']]
Y= df['price']
estimate = [('Scale', StandardScaler()), ('Polynomial', PolynomialFeatures(include_bias=False)), ('model', LinearRegression())]
pipe = pipeline(estimate)
pipe.fit(X,Y)
R2 = pipe.score(X,Y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 11
#       9 Y= df['price']
#      10 estimate = [('Scale', StandardScaler()), ('Polynomial', PolynomialFeatures(include_bias=False)), ('model', LinearRegression())]
# ---> 11 pipe = pipeline(estimate)
#      12 pipe.fit(X,Y)
#      13 R2 = pipe.score(X,Y)
#
# TypeError: 'module' object is not callable

# %%
import pandas as pd
import pipeline as pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
df = pd.read_csv('kc_house_data_NaN.csv')
df.dropna(inplace=True)
X= df[['floors','waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms', 'sqft_living15', 'sqft_above', 'grade', 'sqft_living']]
Y= df['price']
polynomial_reg = Pipeline[('scale', StandardScaler()), ('polynomial', PolynomialFeatures(include_bias=False)), ('model', LinearRegression())]
pipe.fit(X,Y)
R2 = pipe.score(X,Y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 10
#       8 X= df[['floors','waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms', 'sqft_living15', 'sqft_above', 'grade', 'sqft_living']]
#       9 Y= df['price']
# ---> 10 polynomial_reg = Pipeline[('scale', StandardScaler()), ('polynomial', PolynomialFeatures(include_bias=False)), ('model', LinearRegression())]
#      11 pipe.fit(X,Y)
#      12 R2 = pipe.score(X,Y)
#
# TypeError: type 'Pipeline' is not subscriptable

# %%
pip install pipeline

# %%
import pandas as pd
import pipeline as pipeline
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
df = pd.read_csv('kc_house_data_NaN.csv')
df.dropna(inplace=True)
X= df[['floors','waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms', 'sqft_living15', 'sqft_above', 'grade', 'sqft_living']]
Y= df['price']
polynomial_reg = Pipeline[('scale', StandardScaler()), ('polynomial', PolynomialFeatures(include_bias=False)), ('model', LinearRegression())]
pipe.fit(X,Y)
R2 = pipe.score(X,Y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 10
#       8 X= df[['floors','waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms', 'sqft_living15', 'sqft_above', 'grade', 'sqft_living']]
#       9 Y= df['price']
# ---> 10 polynomial_reg = Pipeline[('scale', StandardScaler()), ('polynomial', PolynomialFeatures(include_bias=False)), ('model', LinearRegression())]
#      11 pipe.fit(X,Y)
#      12 R2 = pipe.score(X,Y)
#
# TypeError: type 'Pipeline' is not subscriptable

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
df = pd.read_csv('kc_house_data_NaN.csv')
estimate = [('scale', StandardScaler()), ('polynomial', PolynomialFeatures(include_bias=False)), ('model', LinearRegression())]
pipe.fit(X,Y)
pipe = Pipeline(estimate)
R2 = pipe.score(X,Y)
print("R2:" R2)
# Out:
#   Cell In[51], line 10
#     print("R2:" R2)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
df = pd.read_csv('kc_house_data_NaN.csv')
estimate = [('scale', StandardScaler()), ('polynomial', PolynomialFeatures(include_bias=False)), ('model', LinearRegression())]
pipe.fit(X,Y)
pipe = Pipeline(estimate)
R2 = pipe.score(X,Y)
print("R2:", R2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 7
#       5 df = pd.read_csv('kc_house_data_NaN.csv')
#       6 estimate = [('scale', StandardScaler()), ('polynomial', PolynomialFeatures(include_bias=False)), ('model', LinearRegression())]
# ----> 7 pipe.fit(X,Y)
#       8 pipe = Pipeline(estimate)
#       9 R2 = pipe.score(X,Y)
#
# NameError: name 'pipe' is not defined

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import Pipeline
df = pd.read_csv('kc_house_data_NaN.csv')
estimate = [('scale', StandardScaler()), ('polynomial', PolynomialFeatures(include_bias=False)), ('model', LinearRegression())]
pipe = Pipeline(estimate)
pipe.fit(X,Y)
R2 = pipe.score(X,Y)
print("R2:", R2)
# Out:
# R2: 0.7512012067328004

# %%
import pandas as pd
from sklearn.linear_model import Ridge
df=pd.read_csv('kc_house_data_NaN.csv')
Ridge = Ridge(alpha=0.1)
ridge.fit(x_train,y_train)
R2 = Ridge.score(X_test, Y_test)
print("R2:", r2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 5
#       3 df=pd.read_csv('kc_house_data_NaN.csv')
#       4 Ridge = Ridge(alpha=0.1)
# ----> 5 ridge.fit(x_train,y_train)
#       6 R2 = Ridge.score(X_test, Y_test)
#       7 print("R2:", r2)
#
# NameError: name 'x_train' is not defined

# %%
from sklearn.linear_model import Ridge

# %%
import pandas as pd
from sklearn.linear_model import Ridge
df=pd.read_csv('kc_house_data_NaN.csv')
ridge = Ridge(alpha=0.1)
ridge.fit(x, y)
R2 = Ridge.score(X_test, Y_test)
print("R2:", r2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[63], line 5
#       3 df=pd.read_csv('kc_house_data_NaN.csv')
#       4 ridge = Ridge(alpha=0.1)
# ----> 5 ridge.fit(x, y)
#       6 R2 = Ridge.score(X_test, Y_test)
#       7 print("R2:", r2)
#
# File c:\Users\Kamel\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_ridge.py:1126, in Ridge.fit(self, X, y, sample_weight)
#    1123 self._validate_params()
#    1125 _accept_sparse = _get_valid_accept_sparse(sparse.issparse(X), self.solver)
# -> 1126 X, y = self._validate_data(
#    1127     X,
#    1128     y,
#    1129     accept_sparse=_accept_sparse,
#    1130     dtype=[np.float64, np.float32],
#    1131     multi_output=True,
#    1132     y_numeric=True,
#    1133 )
#    1134 return super().fit(X, y, sample_weight=sample_weight)
#
# ...

# %%
from sklearn.linear_model import Ridge
df=pd.read_csv('kc_house_data_NaN.csv')
ridge = Ridge(alpha=0.1)
ridge.fit(x_train, y_train)
R2 = Ridge.score(X_test, Y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 4
#       2 df=pd.read_csv('kc_house_data_NaN.csv')
#       3 ridge = Ridge(alpha=0.1)
# ----> 4 ridge.fit(x_train, y_train)
#       5 R2 = Ridge.score(X_test, Y_test)
#
# NameError: name 'x_train' is not defined

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
df=pd.read_csv('kc_house_data_NaN.csv')
ridge = Ridge(alpha=0.1)
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,)
ridge.fit(x_train, y_train)
ridge_reg = ridge(alpha=0.1)
ridge_reg.fit(X_train, Y_train)
predict_Y = ridge_reg.predict(X_test)
R2 = R2.score(y_test, Y_test)
print("R2:", R2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 6
#       4 ridge = Ridge(alpha=0.1)
#       5 X_train, X_test, Y_train, Y_test = train_test_split(X,Y,)
# ----> 6 ridge.fit(x_train, y_train)
#       7 ridge_reg = ridge(alpha=0.1)
#       8 ridge_reg.fit(X_train, Y_train)
#
# NameError: name 'x_train' is not defined

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
df=pd.read_csv('kc_house_data_NaN.csv')
ridge = Ridge(alpha=0.1)
X_train, X_test, Y_train, Y_test = train_test_split(X,Y)
ridge.fit(x_train, y_train)
ridge_reg = ridge(alpha=0.1)
ridge_reg.fit(X_train, Y_train)
predict_Y = ridge_reg.predict(X_test)
R2 = R2.score(y_test, Y_test)
print("R2:", R2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[66], line 6
#       4 ridge = Ridge(alpha=0.1)
#       5 X_train, X_test, Y_train, Y_test = train_test_split(X,Y)
# ----> 6 ridge.fit(x_train, y_train)
#       7 ridge_reg = ridge(alpha=0.1)
#       8 ridge_reg.fit(X_train, Y_train)
#
# NameError: name 'x_train' is not defined

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
df=pd.read_csv('kc_house_data_NaN.csv')
ridge = Ridge(alpha=0.1)
X_train, X_test, Y_train, Y_test = train_test_split(df[['floors', 'waterfront', 'lat', 'bedrooms']])
ridge.fit(x_train, y_train)
ridge_reg = ridge(alpha=0.1)
ridge_reg.fit(X_train, Y_train)
predict_Y = ridge_reg.predict(X_test)
R2 = R2.score(y_test, Y_test)
print("R2:", R2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 5
#       3 df=pd.read_csv('kc_house_data_NaN.csv')
#       4 ridge = Ridge(alpha=0.1)
# ----> 5 X_train, X_test, Y_train, Y_test = train_test_split(df[['floors', 'waterfront', 'lat', 'bedrooms']])
#       6 ridge.fit(x_train, y_train)
#       7 ridge_reg = ridge(alpha=0.1)
#
# ValueError: not enough values to unpack (expected 4, got 2)

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
df=pd.read_csv('kc_house_data_NaN.csv')
ridge = Ridge(alpha=0.1)
X_train, X_test, Y_train, Y_test = train_test_split(df[['floors', 'waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms', 'sqftliving15']])
ridge.fit(x_train, y_train)
ridge_reg = ridge(alpha=0.1)
ridge_reg.fit(X_train, Y_train)
predict_Y = ridge_reg.predict(X_test)
R2 = R2.score(y_test, Y_test)
print("R2:", R2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[69], line 5
#       3 df=pd.read_csv('kc_house_data_NaN.csv')
#       4 ridge = Ridge(alpha=0.1)
# ----> 5 X_train, X_test, Y_train, Y_test = train_test_split(df[['floors', 'waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms', 'sqftliving15']])
#       6 ridge.fit(x_train, y_train)
#       7 ridge_reg = ridge(alpha=0.1)
#
# File c:\Users\Kamel\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# ...

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
df=pd.read_csv('kc_house_data_NaN.csv')
ridge = Ridge(alpha=0.1)
X_train, X_test, Y_train, Y_test = train_test_split(df[['floors', 'waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms','sqft_living15', 'sqft_above', 'grade', 'sqft_living']])
ridge.fit(x_train, y_train)
ridge_reg = ridge(alpha=0.1)
ridge_reg.fit(X_train, Y_train)
predict_Y = ridge_reg.predict(X_test)
R2 = R2.score(y_test, Y_test)
print("R2:", R2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 5
#       3 df=pd.read_csv('kc_house_data_NaN.csv')
#       4 ridge = Ridge(alpha=0.1)
# ----> 5 X_train, X_test, Y_train, Y_test = train_test_split(df[['floors', 'waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms','sqft_living15', 'sqft_above', 'grade', 'sqft_living']])
#       6 ridge.fit(x_train, y_train)
#       7 ridge_reg = ridge(alpha=0.1)
#
# ValueError: not enough values to unpack (expected 4, got 2)

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import train_test_split
df=pd.read_csv('kc_house_data_NaN.csv')
X_train, X_test, Y_train, Y_test = train_test_split(df[['floors', 'waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms','sqft_living15', 'sqft_above', 'grade', 'sqft_living']])
ridge.fit(x_train, y_train)
ridge_reg = ridge(alpha=0.1)
ridge_reg.fit(X_train, Y_train)
predict_Y = ridge_reg.predict(X_test)
R2 = R2.score(y_test, Y_test)
print("R2:", R2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 4
#       2 from sklearn.model_selection import train_test_split
#       3 df=pd.read_csv('kc_house_data_NaN.csv')
# ----> 4 X_train, X_test, Y_train, Y_test = train_test_split(df[['floors', 'waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms','sqft_living15', 'sqft_above', 'grade', 'sqft_living']])
#       5 ridge.fit(x_train, y_train)
#       6 ridge_reg = ridge(alpha=0.1)
#
# ValueError: not enough values to unpack (expected 4, got 2)

# %%
from sklearn.linear_model import Ridge
import pandas as pd
from sklearn.model_selection import train_test_split
df=pd.read_csv('kc_house_data_NaN.csv')
X_train, X_test, Y_train, Y_test = train_test_split(df[['floors', 'waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms','sqft_living15', 'sqft_above', 'grade', 'sqft_living']])
ridge.fit(x_train, y_train)
ridge_reg = ridge(alpha=0.1)
ridge_reg.fit(X_train, Y_train)
predict_Y = ridge_reg.predict(X_test)
R2 = R2.score(y_test, Y_test)
print("R2:", R2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[72], line 5
#       3 from sklearn.model_selection import train_test_split
#       4 df=pd.read_csv('kc_house_data_NaN.csv')
# ----> 5 X_train, X_test, Y_train, Y_test = train_test_split(df[['floors', 'waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms','sqft_living15', 'sqft_above', 'grade', 'sqft_living']])
#       6 ridge.fit(x_train, y_train)
#       7 ridge_reg = ridge(alpha=0.1)
#
# ValueError: not enough values to unpack (expected 4, got 2)

# %%
from sklearn.linear_model import Ridge
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
df=pd.read_csv('kc_house_data_NaN.csv')
X_train, X_test, Y_train, Y_test = train_test_split(df[['floors', 'waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms','sqft_living15', 'sqft_above', 'grade', 'sqft_living']])
ridge.fit(x_train, y_train)
ridge_reg = ridge(alpha=0.1)
ridge_reg.fit(X_train, Y_train)
predict_Y = ridge_reg.predict(X_test)
R2 = R2.score(y_test, Y_test)
print("R2:", R2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 6
#       4 from sklearn.metrics import r2_score
#       5 df=pd.read_csv('kc_house_data_NaN.csv')
# ----> 6 X_train, X_test, Y_train, Y_test = train_test_split(df[['floors', 'waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms','sqft_living15', 'sqft_above', 'grade', 'sqft_living']])
#       7 ridge.fit(x_train, y_train)
#       8 ridge_reg = ridge(alpha=0.1)
#
# ValueError: not enough values to unpack (expected 4, got 2)

# %%
from sklearn.linear_model import Ridge
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
df = pd.read_csv('kc_house_data_NaN.csv')
df = dropna(inplace=True)
X_train, X_test, Y_train, Y_test = train_test_split(df[['floors', 'waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms','sqft_living15', 'sqft_above', 'grade', 'sqft_living']])
ridge.fit(x_train, y_train)
ridge_reg = ridge(alpha=0.1)
ridge_reg.fit(X_train, Y_train)
predict_Y = ridge_reg.predict(X_test)
R2 = R2.score(y_test, Y_test)
print("R2:", R2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[74], line 6
#       4 from sklearn.metrics import r2_score
#       5 df = pd.read_csv('kc_house_data_NaN.csv')
# ----> 6 df = dropna(inplace=True)
#       7 X_train, X_test, Y_train, Y_test = train_test_split(df[['floors', 'waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms','sqft_living15', 'sqft_above', 'grade', 'sqft_living']])
#       8 ridge.fit(x_train, y_train)
#
# NameError: name 'dropna' is not defined

# %%
from sklearn.linear_model import Ridge
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
df = pd.read_csv('kc_house_data_NaN.csv')
df.dropna(inplace=True)
X_train, X_test, Y_train, Y_test = train_test_split(df[['floors', 'waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms','sqft_living15', 'sqft_above', 'grade', 'sqft_living']])
ridge.fit(x_train, y_train)
ridge_reg = ridge(alpha=0.1)
ridge_reg.fit(X_train, Y_train)
predict_Y = ridge_reg.predict(X_test)
R2 = R2.score(y_test, Y_test)
print("R2:", R2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[75], line 7
#       5 df = pd.read_csv('kc_house_data_NaN.csv')
#       6 df.dropna(inplace=True)
# ----> 7 X_train, X_test, Y_train, Y_test = train_test_split(df[['floors', 'waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms','sqft_living15', 'sqft_above', 'grade', 'sqft_living']])
#       8 ridge.fit(x_train, y_train)
#       9 ridge_reg = ridge(alpha=0.1)
#
# ValueError: not enough values to unpack (expected 4, got 2)

# %%
from sklearn.linear_model import Ridge
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score
df = pd.read_csv('kc_house_data_NaN.csv')
df.dropna(inplace=True)
X_train, X_test, Y_train, Y_test = train_test_split(df[['floors', 'waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms','sqft_living15', 'sqft_above', 'grade', 'sqft_living']])
ridge.fit(x_train, y_train)
ridge_reg = ridge(alpha=0.1)
ridge_reg.fit(X_train, Y_train)
predict_Y = ridge_reg.predict(X_test)
R2 = R2.score(y_test, Y_test)
print("R2:", R2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[76], line 8
#       6 df = pd.read_csv('kc_house_data_NaN.csv')
#       7 df.dropna(inplace=True)
# ----> 8 X_train, X_test, Y_train, Y_test = train_test_split(df[['floors', 'waterfront', 'lat', 'bedrooms', 'sqft_basement', 'view', 'bathrooms','sqft_living15', 'sqft_above', 'grade', 'sqft_living']])
#       9 ridge.fit(x_train, y_train)
#      10 ridge_reg = ridge(alpha=0.1)
#
# ValueError: not enough values to unpack (expected 4, got 2)

# %%
pip install ridge
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> [6 lines of output]
#       Traceback (most recent call last):
#         File "<string>", line 2, in <module>
#         File "<pip-setuptools-caller>", line 34, in <module>
#         File "C:\Users\Kamel\AppData\Local\Temp\pip-install-befznay1\ridge_2b7f2609125e44f29b86aa1141c9fd38\setup.py", line 4, in <module>
#           from Cython.Distutils import build_ext
#       ModuleNotFoundError: No module named 'Cython'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# ...

# %%
from sklearn.linear_model import Ridge
import pandas as pd
from sklearn.model_selection import train_test_split
df = pd.read_csv('kc_house_data_NaN.csv')
R2=Ridge(alpha=0.1)
R2.fit(X_train,Y_train)
R2.score(X_test,Y_test)
# Out:
# 0.6371386901454714

# %%
from sklearn.preprocessing import PolynomialFeatures
import pandas as pd
pln = polynomialFeatures(degree=2)
X_train_pln = pln.Fit_transForm(X_train)
X_test_pln = pln.Fit_transForm(X_test)
R2 = ridge(alpha=0.1)
R2.fit(X_train,Y_train)
R2.score(X_test_pln,Y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[89], line 3
#       1 from sklearn.preprocessing import PolynomialFeatures
#       2 import pandas as pd
# ----> 3 pln = polynomialFeatures(degree=2)
#       4 X_train_pln = pln.Fit_transForm(X_train)
#       5 X_test_pln = pln.Fit_transForm(X_test)
#
# NameError: name 'polynomialFeatures' is not defined

# %%
from sklearn.preprocessing import PolynomialFeatures
pr = polynomialFeatures(degree=2)
X_train_pr = pr.Fit_transForm(X_train)
X_test_pr = pr.Fit_transForm(X_test)
R2 = ridge(alpha=0.1)
R2.fit(X_train,Y_train)
R2.score(X_test_pln,Y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[91], line 2
#       1 from sklearn.preprocessing import PolynomialFeatures
# ----> 2 pr = polynomialFeatures(degree=2)
#       3 X_train_pr = pr.Fit_transForm(X_train)
#       4 X_test_pr = pr.Fit_transForm(X_test)
#
# NameError: name 'polynomialFeatures' is not defined

# %%
import polynomialFeatures
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 import polynomialFeatures
#
# ModuleNotFoundError: No module named 'polynomialFeatures'

# %%
pip install polynomialFeatures
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement polynomialFeatures (from versions: none)
# ERROR: No matching distribution found for polynomialFeatures

# %%
 import polynomialFeatures
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 import polynomialFeatures
#
# ModuleNotFoundError: No module named 'polynomialFeatures'

# %%
import numpy as np
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import Ridge
pr = PolynomialFeatures(degree=2)
X_train_pr = pr.fit_transform(X_train)
X_test_pr = pr.fit_transform(X_test)
R2 = Ridge(alpha=0.1)
R2.fit(X_train_pr,Y_train)
R2.score(X_test_pr,Y_test)
# Out:
# 0.6660669487552812
